# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
from bs4 import BeautifulSoup as bs
import requests
import lxml
import html5lib
import time
import random
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %% [markdown]
# ## Get the 250 TV Series with the highest average rating.

# %%
# Page with highest rating average 250 TV series
URL = "https://www.imdb.com/chart/toptv/?ref_=nv_tvv_50"
page = requests.get(URL)
soup = bs(page.content, "lxml")

# %%
top_list = pd.DataFrame(columns=["series_name", "series_rank", "series_origin_year", "series_link"])
top_list
# Out:
# Empty DataFrame
# Columns: [series_name, series_rank, series_origin_year, series_link]
# Index: []

# %%
all_series = soup.find_all('td', class_='titleColumn')

for ser in all_series:
    
    series_link = ser.find("a")
    
    series_rank = (
        ser
        .text
        .split(".")[0]
        .strip()
    )
    
    series_title = (
        ser
        .text
        .split(".")[1]
        .split("(")[0]
        .strip()
    )
    series_year = (
        ser
        .text
        .split("(")[1]
        .replace(")", "")
        .strip()
    )
    
    row = {
    "series_name": series_title, 
    "series_rank": series_rank,
    "series_origin_year": series_year,
    "series_link": series_link["href"]
      }
    
    top_list = top_list.append(row, ignore_index=True)

# %%
top_list.head(5)
# Out:
#         series_name series_rank series_origin_year        series_link
# 0   Planet Earth II           1               2016  /title/tt5491994/
# 1      Planet Earth           2               2006  /title/tt0795176/
# 2      Breaking Bad           3               2008  /title/tt0903747/
# 3  Band of Brothers           4               2001  /title/tt0185906/
# 4         Chernobyl           5               2019  /title/tt7366338/

# %%
# Pickle or read pickled data. 
    
# PICKLE
# top_list.to_pickle("top_series.pkl")

# READ
top_list = pd.read_pickle("top_series.pkl")

# %%
# This is a way of dealing with series with similar names (e.g. House of Cards)
top_list['series_id'] = top_list['series_name'] + " (" + top_list['series_origin_year'] + ")"

# %%
top_list.head(5)
# Out:
#         series_name series_rank series_origin_year        series_link  \
# 0   Planet Earth II           1               2016  /title/tt5491994/
# 1      Planet Earth           2               2006  /title/tt0795176/
# 2      Breaking Bad           3               2008  /title/tt0903747/
# 3  Band of Brothers           4               2001  /title/tt0185906/
# 4         Chernobyl           5               2019  /title/tt7366338/
#
#                  series_id
# 0   Planet Earth II (2016)
# 1      Planet Earth (2006)
# 2      Breaking Bad (2008)
# 3  Band of Brothers (2001)
# 4         Chernobyl (2019)

# %% [markdown]
# ## Function: How to know the number of seasons per series.

# %%
# https://stackoverflow.com/questions/23013220/max-retries-exceeded-with-url-in-requests
session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# %%
# Get the number of seasons for a certain series
def get_last_season(series_name):
    
    print("########################################################################################")
    print(f"SCRAPING: {series_name.upper()}")
    
    # Add some random sleep time between each request toward IMDB.
    time.sleep(random.randint(5,15))
    
    # Get the URL and id based on mapping between series title and series link.
    try: 
        series_link = top_list[top_list['series_name']==f"{series_name}"]['series_link'].item()
    except ValueError:
        print(f"{series_name.upper()} references more than one series. Exclude it from the dataset.")
    
    # Send request and get soup.
    URL = f"https://www.imdb.com{series_link}"
    page = session.get(URL) # Write "session" instead of "requests" to deal with connection errors.
    soup = bs(page.content, "lxml")

    max_season = soup.find("select", id="browse-episodes-season")

    # The "browse episodes" button only exists if there are multiple seasons. 
    if max_season is None:
        max_season = 1
    else:
        max_season = int(max_season['aria-label'].split(' ')[0])
        
    print(f"##### TOTAL SEASONS: {max_season}")
            
    return(max_season)

# %% [markdown]
# ## Function: How to scrape all the episode data per series and season.

# %%
def get_ratings(series_name):
    
    # Get the URL based on mapping between series title and series link.
    try: 
        series_link = top_list[top_list['series_name']==f"{series_name}"]['series_link'].item()
    except ValueError:
        print(f"{series_name.upper()} references more than one series. Exclude it from the dataset.")
    
    # Create empty dataframe.
    df = pd.DataFrame(columns=["series_name", 
                               "series_rank", 
                               "series_origin_year", 
                               "series_link",
                               "series_n_seasons",
                               "season",
                               "episode",
                               "episode_rating",
                               "episode_total_votes",
                               "episode_description"
                              ])
    
    # Get the max number of seasons.
    seasons = get_last_season(series_name)
    
    print(f"##### GETTING EPISODES...")
    
    # Loop through each season for a series.
    for season in np.arange(1, seasons+1):
        
        # Add some random sleep time between each request toward IMDB.
        time.sleep(random.randint(5,15))
        
        # Get the soup for each season's IMDB URL page.
        URL = f"https://www.imdb.com{series_link}episodes?season={season}"
        page = session.get(URL) # Write "session" instead of "requests" to deal with connection errors.
        soup = bs(page.content, "lxml")
        
        # Get all info for all episodes in selected season.
        all_episode_info = soup.find_all(class_="info")

        for episode in all_episode_info:
            
            # Get episode description
            try: 
                description = (
                    episode
                    .find("div", class_="item_description")
                    .text
                    .strip()
                )
            except AttributeError:
                description = "N/A"
            # Get episode rating
            rating = (
                episode
                .find("span", class_="ipl-rating-star__rating")
                .text
            ) # There are actually several of this object. Luckily, the first one is the one we're looking for.
            # Get episode total votes
            total_votes = (
                episode
                .find("span", class_="ipl-rating-star__total-votes")
                .text
                .replace("(", "")
                .replace(")", "")
                .replace(',', '')
            )
            # Get episode number
            number = episode.find("meta", itemprop="episodeNumber")
            
            row = {
                "series_name": series_name, 
                "series_rank": top_list[top_list['series_name']==series_name]['series_rank'].item(),
                "series_origin_year": top_list[top_list['series_name']==series_name]['series_origin_year'].item(),
                "series_link": series_link,
                "series_n_seasons": seasons,
                "season": season,
                "episode": number["content"],
                "episode_rating": rating,
                "episode_total_votes": total_votes,
                "episode_description": description
            }
            
            df = df.append(row, ignore_index=True)
            
        print(f"######## SEASON {season} SCRAPED")
            
    print(f"{series_name.upper()} - TOTAL EPISODES: {len(df)}")
    print("########################################################################################")
    
    df = df.astype(
        {
            'series_name': 'str', 
            'series_rank': 'int64',
            'series_origin_year': 'int64',
            'series_link': 'str', 
            'series_n_seasons': 'int64',
            'season': 'int64',
            'episode': 'int64',
            'episode_rating': 'float64',
            'episode_total_votes': 'int64',
            'episode_description': 'str'
        }
    )
            
    return(df)

# %% [markdown]
# ## Actual data scraping

# %%
episodes = pd.DataFrame(columns=["series_name", 
                                 "series_rank", 
                                 "series_origin_year", 
                                 "series_link",
                                 "series_n_seasons",
                                 "season",
                                 "episode",
                                 "episode_rating",
                                 "episode_total_votes",
                                 "episode_description"
                                ])
episodes
# Out:
# Empty DataFrame
# Columns: [series_name, series_rank, series_origin_year, series_link, series_n_seasons, season, episode, episode_rating, episode_total_votes, episode_description]
# Index: []

# %%
top_list[70:].head(5)
# Out:
#             series_name series_rank series_origin_year        series_link  \
# 70           Invincible          71               2021  /title/tt6741278/
# 71                 Rome          72               2005  /title/tt0384766/
# 72        Dragon Ball Z          73               1996  /title/tt0214341/
# 73  Simma lugnt, Larry!          74               2000  /title/tt0264235/
# 74        Jag, Claudius          75               1976  /title/tt0074006/
#
#                      series_id
# 70           Invincible (2021)
# 71                 Rome (2005)
# 72        Dragon Ball Z (1996)
# 73  Simma lugnt, Larry! (2000)
# 74        Jag, Claudius (1976)

# %%
# One problem to solve: Series with identical names (e.g. House of Cards)

# %%
# SELECT SHOWS TO SCRAPE

# Based on top ranking
N_SERIES = 50
series_list = list(top_list.head(N_SERIES)['series_name'])

# Based on taste
#series_list = [
#    "Game of Thrones", 
#    "The Wire", 
#    "The Sopranos", 
#    "Breaking Bad", 
#    "True Detective", 
#    "Peaky Blinders", 
#    "Rome", 
#    "Mad Men",
#    "Parks and Recreation", 
#    "Dexter"
#]

# %%
n = 0

# Apply scraper!
for ser in series_list:
    
    n = n + 1
    print(f"{n}/{N_SERIES}")
    
    # Run through all the series's seasons and extract episode data.
    df = get_ratings(series_name=ser)
    
    # Concatenate episode data to the main dataset.
    episodes = pd.concat([episodes, df])
    
episodes = episodes.reset_index()
# Out:
# 1/50
# ########################################################################################
# SCRAPING: PLANET EARTH II
# ##### TOTAL SEASONS: 1
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# PLANET EARTH II - TOTAL EPISODES: 6
# ########################################################################################
# 2/50
# ########################################################################################
# SCRAPING: PLANET EARTH
# ##### TOTAL SEASONS: 1
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# PLANET EARTH - TOTAL EPISODES: 11
# ########################################################################################
# 3/50
# ########################################################################################
# SCRAPING: BREAKING BAD
# ##### TOTAL SEASONS: 5
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# ######## SEASON 2 SCRAPED
# ######## SEASON 3 SCRAPED
# ######## SEASON 4 SCRAPED
# ######## SEASON 5 SCRAPED
# BREAKING BAD - TOTAL EPISODES: 62
# ########################################################################################
# 4/50
# ########################################################################################
# SCRAPING: BAND OF BROTHERS
# ##### TOTAL SEASONS: 1
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# BAND OF BROTHERS - TOTAL EPISODES: 10
# ########################################################################################
# 5/50
# ########################################################################################
# SCRAPING: CHERNOBYL
# ##### TOTAL SEASONS: 1
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# CHERNOBYL - TOTAL EPISODES: 5
# ########################################################################################
# 6/50
# ########################################################################################
# SCRAPING: THE WIRE
# ##### TOTAL SEASONS: 5
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# ######## SEASON 2 SCRAPED
# ######## SEASON 3 SCRAPED
# ######## SEASON 4 SCRAPED
# ######## SEASON 5 SCRAPED
# THE WIRE - TOTAL EPISODES: 60
# ########################################################################################
# 7/50
# ########################################################################################
# SCRAPING: BLUE PLANET II
# ##### TOTAL SEASONS: 1
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# BLUE PLANET II - TOTAL EPISODES: 7
# ########################################################################################
# 8/50
# ########################################################################################
# SCRAPING: OUR PLANET
# ##### TOTAL SEASONS: 1
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# OUR PLANET - TOTAL EPISODES: 8
# ########################################################################################
# 9/50
# ########################################################################################
# SCRAPING: COSMOS: A SPACETIME ODYSSEY
# ##### TOTAL SEASONS: 1
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# COSMOS: A SPACETIME ODYSSEY - TOTAL EPISODES: 13
# ########################################################################################
# 10/50
# ########################################################################################
# SCRAPING: AVATAR - LEGENDEN OM AANG
# ##### TOTAL SEASONS: 3
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# ######## SEASON 2 SCRAPED
# ######## SEASON 3 SCRAPED
# AVATAR - LEGENDEN OM AANG - TOTAL EPISODES: 62
# ########################################################################################
# 11/50
# ########################################################################################
# SCRAPING: KOSMOS
# ##### TOTAL SEASONS: 1
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# KOSMOS - TOTAL EPISODES: 13
# ########################################################################################
# 12/50
# ########################################################################################
# SCRAPING: GAME OF THRONES
# ##### TOTAL SEASONS: 8
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# ######## SEASON 2 SCRAPED
# ######## SEASON 3 SCRAPED
# ######## SEASON 4 SCRAPED
# ######## SEASON 5 SCRAPED
# ######## SEASON 6 SCRAPED
# ######## SEASON 7 SCRAPED
# ######## SEASON 8 SCRAPED
# GAME OF THRONES - TOTAL EPISODES: 73
# ########################################################################################
# 13/50
# ########################################################################################
# SCRAPING: THE SOPRANOS
# ##### TOTAL SEASONS: 6
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# ######## SEASON 2 SCRAPED
# ######## SEASON 3 SCRAPED
# ######## SEASON 4 SCRAPED
# ######## SEASON 5 SCRAPED
# ######## SEASON 6 SCRAPED
# THE SOPRANOS - TOTAL EPISODES: 86
# ########################################################################################
# 14/50
# ########################################################################################
# SCRAPING: RICK AND MORTY
# ##### TOTAL SEASONS: 5
# ##### GETTING EPISODES...
# ######## SEASON 1 SCRAPED
# ######## SEASON 2 SCRAPED
# ######## SEASON 3 SCRAPED
# ######## SEASON 4 SCRAPED
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_p/cytfx8ds7rddgyf8_ggylgv40000gn/T/ipykernel_82010/862233727.py in <module>
#       8
#       9     # Run through all the series's seasons and extract episode data.
# ---> 10     df = get_ratings(series_name=ser)
#      11
#      12     # Concatenate episode data to the main dataset.
#
# /var/folders/_p/cytfx8ds7rddgyf8_ggylgv40000gn/T/ipykernel_82010/3615902711.py in get_ratings(series_name)
#      60                 "season": season,
#      61                 "episode": number["content"],
# ---> 62                 "episode_rating": rating.text,
#      63                 "episode_total_votes": total_votes.text.replace("(", "").replace(")", "").replace(',', ''),
#      64                 "episode_description": description.text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Pickle or read pickled data. 
    
# PICKLE
#episodes.to_pickle("episode_data.pkl")
#episodes.to_pickle("episode2_data.pkl")

# READ
#episodes = pd.read_pickle("episode_data.pkl")

# %% [markdown]
# ## Analyse data

# %%
episodes.sample(2)
# Out:
#      series_name series_rank series_origin_year        series_link  \
# 4         Kosmos          11               1980  /title/tt0081846/
# 61  The Sopranos          13               1999  /title/tt0141842/
#
#    series_n_seasons season episode  episode_rating episode_total_votes  \
# 4                 1      1       5             8.9                 464
# 61                6      5      10             8.7                4153
#
#                                   episode_description
# 4   Carl Sagan looks at the search for life on Mar...
# 61  Chris and cousin Tony do some digging to make ...

# %%
# Fix types.
episodes['season_episode'] = episodes['season'].astype(str).str.zfill(2) + ":" + episodes['episode'].astype(str).str.zfill(2)

# %%
episodes.sample(2)
# Out:
#         series_name series_rank series_origin_year        series_link  \
# 4   Game of Thrones          12               2011  /title/tt0944947/
# 67     The Sopranos          13               1999  /title/tt0141842/
#
#    series_n_seasons season episode  episode_rating episode_total_votes  \
# 4                 8      1       5             9.1               31319
# 67                6      6       3             8.8                4325
#
#                                   episode_description season_episode
# 4   Catelyn has captured Tyrion and plans to bring...          01:05
# 67  While the gang begins to turn on itself, Tony ...          06:03

# %% [markdown]
# ## Visualise data

# %%
episodes.series_name.unique()
# Out:
# array(['Planet Earth II', 'Planet Earth', 'Breaking Bad',
#        'Band of Brothers', 'Chernobyl', 'The Wire', 'Blue Planet II',
#        'Our Planet', 'Cosmos: A Spacetime Odyssey',
#        'Avatar - Legenden om Aang', 'Kosmos', 'Game of Thrones',
#        'The Sopranos'], dtype=object)

# %%
SELECTED_SERIES_LIST = ["Game of Thrones", 
                        "Breaking Bad", 
                        "The Wire", 
                        "The Sopranos"
                       ]

temp_data = episodes.query(f'series_name in {SELECTED_SERIES_LIST}')

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set_style('white')
sns.set_context("poster")

#sns.lineplot(data=temp_data, x="season_episode", y="episode_rating");

plt.title("Title", size=24)

g = sns.lineplot(data=temp_data.sort_values('season_episode'), 
                 x='season_episode', 
                 y="episode_rating", 
                 markers=True,
                 dashes=False,
                 hue="series_name",
                 #style="series_n_seasons",
                 lw=5, 
                 alpha=1, 
                 palette="coolwarm");

plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.xlabel("Season:Episode")
plt.ylabel("Average rating per episode")
plt.xticks(rotation=90);

# %% [markdown]
# ## Extra

# %%
df = episodes.query('series_name in ("Game of Thrones")')

sns.set(rc={'figure.figsize':(30,30)})
sns.set_style('white')
sns.set_context("poster")

# Plot each year's time series in its own facet
g = sns.relplot(
    data=df,
    x="episode", y="episode_rating", col="season", hue="season",
    kind="line", palette="crest", linewidth=4, zorder=5,
    col_wrap=2, height=4, aspect=2, legend=False,
)

# Iterate over each subplot to customize further
for season, ax in g.axes_dict.items():

    # Add the title as an annotation within the plot
    ax.text(.8, .85, season, transform=ax.transAxes, fontweight="bold")

    # Plot every year's time series in the background
    sns.lineplot(
        data=df, x="episode", y="episode_rating", units="season",
        estimator=None, color=".7", linewidth=1, ax=ax,
    )

# Reduce the frequency of the x axis ticks
ax.set_xticks(ax.get_xticks()[::2])

# Tweak the supporting aspects of the plot
g.set_titles("")
g.set_axis_labels("", "X")
g.tight_layout()

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set_style('white')
sns.set_context("poster")

#sns.lineplot(data=temp_data, x="season_episode", y="episode_rating");

plt.title("Title", size=24)

g = sns.lineplot(data=episodes.sort_values('season_episode'), 
                 x='season_episode', 
                 y="episode_rating", 
                 markers=True,
                 dashes=False,
                 #hue="series_name",
                 #style="series_n_seasons",
                 lw=5, 
                 alpha=1, 
                 palette="coolwarm");

plt.xlabel("Season:Episode")
plt.ylabel("Average rating per episode")
plt.xticks(rotation=90);

# %%
episodes['total_rating'] = episodes['episode_rating'] * episodes['episode_total_votes']

# %%
seasons = (
    episodes
    .groupby(['series_name', 'season'])
    .aggregate({'episode_total_votes': 'sum', 'total_rating': 'sum'})
    .reset_index()
    .assign(average_rating=lambda x: round(x['total_rating'] / x['episode_total_votes'],1))
    .assign(previous_average_rating=lambda x: x['average_rating'].shift(1))
    .assign(rating_change=lambda x: round(x['average_rating'] / x['previous_average_rating'],2)-1)
    .drop(columns=['total_rating'])
)

# %%
seasons.head(4)
# Out:
#                  series_name  season  episode_total_votes  average_rating  \
# 0  Avatar - Legenden om Aang       1                68611             8.4
# 1  Avatar - Legenden om Aang       2                64745             8.8
# 2  Avatar - Legenden om Aang       3                76291             9.1
# 3           Band of Brothers       1                68770             9.1
#
#    previous_average_rating  rating_change
# 0                      NaN            NaN
# 1                      8.4           0.05
# 2                      8.8           0.03
# 3                      9.1           0.00

# %%
sns.set(rc={'figure.figsize':(30,30)})
sns.set_style('white')
sns.set_context("poster")

# Plot each year's time series in its own facet
g = sns.relplot(
    data=seasons,
    x="season", y="average_rating", col="series_name", hue="series_name",
    kind="line", palette="crest", linewidth=4, zorder=5,
    col_wrap=2, height=5, aspect=2, legend=False,
)

# Iterate over each subplot to customize further
for series_name, ax in g.axes_dict.items():

    # Add the title as an annotation within the plot
    ax.text(.05, .1, series_name, transform=ax.transAxes, fontweight="bold")

    # Plot every year's time series in the background
    sns.lineplot(
        data=seasons, x="season", y="average_rating", units="series_name",
        estimator=None, color=".7", linewidth=1, ax=ax,
    )

# Reduce the frequency of the x axis ticks
ax.set_xticks(ax.get_xticks()[::2])

# Tweak the supporting aspects of the plot
g.set_titles("")
g.set_axis_labels("", "Season Rating")
g.tight_layout()

# %%
sns.set(rc={'figure.figsize':(30,15)})
sns.set_style('white')
sns.set_context("poster")

#sns.lineplot(data=temp_data, x="season_episode", y="episode_rating");

plt.title("Title", size=24)

g = sns.lineplot(data=seasons.sort_values('season'), 
                 x='season', 
                 y="rating_change", 
                 markers=True,
                 dashes=False,
                 hue="series_name",
                 #style="series_n_seasons",
                 lw=5, 
                 alpha=1, 
                 palette="coolwarm");

plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.xlabel("Season:Episode")
plt.ylabel("Average rating per episode")
plt.xticks(rotation=90);
